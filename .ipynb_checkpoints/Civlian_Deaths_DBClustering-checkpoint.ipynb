# %%
import pandas as pd

# %%
civ_df = pd.read_csv('Violence_against_civilians.csv')
civ_df
# Out:
#        Unnamed: 0                                             actor1  \
# 0               0                                    B-18: Barrio-18
# 1               1                         Unidentified Gang (Mexico)
# 2               2            Unidentified Gang and/or Police Militia
# 3               3                     Police Forces of Kenya (2013-)
# 4               4                         Unidentified Gang (Mexico)
# 5               5                  Unidentified Armed Group (Mexico)
# 6               6                  Unidentified Armed Group (Mexico)
# 7               7                  Unidentified Armed Group (Mexico)
# 8               8                              Hindu Militia (India)
# 9               9  CNDD-FDD-Imbonerakure: National Council for th...
# 10             10     Unidentified Armed Group (Trinidad and Tobago)
# 11             11     Military Forces of Syria (2000-) Prison Guards
# 12             12                    Police Forces of Turkey (2016-)
# ...

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
loc = civ_df[["latitude", "longitude"]]
loc
# Out:
#        latitude  longitude
# 0       13.5894   -89.2383
# 1       19.9682  -101.1396
# 2       -8.0694   -37.2684
# 3       -3.3543    40.0209
# 4       18.6000   -99.3695
# 5       19.1903   -96.1530
# 6       31.7465  -106.4850
# 7       20.2519   -99.6454
# 8       25.5941    85.1356
# 9       -3.0451    30.1592
# 10      10.6667   -61.5189
# 11      33.6653    36.3290
# 12      41.0369    28.9775
# 13      19.0532  -104.3164
# 14      24.3655    84.2459
# 15      15.4000   -87.8000
# 16      15.2574   -89.1009
# 17      10.0647   -69.3570
# 18      37.0447    41.2262
# 19       6.2239   125.0692
# 20       7.7102    81.6924
# 21      22.8773  -102.5410
# 22     -26.1833    28.3167
# 23      14.8138   121.0452
# 24      22.3571    91.7823
# 25      10.6159    13.3849
# 26      10.7447    13.3325
# 27      14.6042   120.9822
# 28      19.3590   -99.0926
# 29     -10.1675   -48.3277
# ...         ...        ...
# 22695   19.4829   -99.1135
# 22696   35.4598    36.7465
# ...

# %%
db = DBSCAN(eps = .3, min_samples = 10).fit(loc)
label = db.labels_
print (label[500:600])
civ_df['Clus_Db']= labels
# Out:
# [ 25  56  -1  -1  -1  -1   6   6  85   2  -1   1   8  -1   1   6  -1  71
#   71  -1  15  30  43   2  46  46   8  83  86  86  42 107  -1  69   8   6
#   34   6  -1  -1 108  -1 109   1  -1 111  24  43 253  56  -1  85  15  30
#    0   2  25  20  -1  -1  23  -1  71  -1  15   6  -1 110  -1 164  -1   6
#   30  95  36  -1  34  52  20  43  -1  19  -1  -1  20  27  -1  -1  -1  56
#   -1  -1 258   1  -1   1 111   6 112 113]

# %%
civ_df
# Out:
#        Unnamed: 0                                             actor1  \
# 0               0                                    B-18: Barrio-18
# 1               1                         Unidentified Gang (Mexico)
# 2               2            Unidentified Gang and/or Police Militia
# 3               3                     Police Forces of Kenya (2013-)
# 4               4                         Unidentified Gang (Mexico)
# 5               5                  Unidentified Armed Group (Mexico)
# 6               6                  Unidentified Armed Group (Mexico)
# 7               7                  Unidentified Armed Group (Mexico)
# 8               8                              Hindu Militia (India)
# 9               9  CNDD-FDD-Imbonerakure: National Council for th...
# 10             10     Unidentified Armed Group (Trinidad and Tobago)
# 11             11     Military Forces of Syria (2000-) Prison Guards
# 12             12                    Police Forces of Turkey (2016-)
# ...

# %%
civ_df.groupby(['Animal']).mean()
